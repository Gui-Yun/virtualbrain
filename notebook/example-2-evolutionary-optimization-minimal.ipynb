# %% [markdown]
# # Simple example of the evolutionary optimization framework
#
# This notebook provides a simple example for the use of the evolutionary optimization framework builtin to the library. Under the hood, the implementation of the evolutionary algorithm is powered by `deap` and `pypet` cares about the parallelization and storage of the simulation data for us.
#
# Here we demonstrate how to fit parameters of a the evaluation function `optimize_me` which simply computes the distance of the parameters to the unit circle and returns this as the `fitness_tuple` that DEAP expects.

# %%
# change to the root directory of the project
import os
if os.getcwd().split("/")[-1] == "examples":
    os.chdir('..')
    
# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2

# %%
try:
    import matplotlib.pyplot as plt
except ImportError:
    import sys
    # !{sys.executable} -m pip install matplotlib seaborn
    import matplotlib.pyplot as plt
    
import numpy as np
import logging

from neurolib.utils.parameterSpace import ParameterSpace
from neurolib.optimize.evolution import Evolution

import neurolib.optimize.evolution.evolutionaryUtils as eu
import neurolib.utils.functions as func

def optimize_me(traj):
    ind = evolution.getIndividualFromTraj(traj)
    logging.info("Hello, I am {}".format(ind.id))
    logging.info("You can also call me {}, or simply ({:.2}, {:.2}).".format(ind.params, ind.x, ind.y))
    
    # let's make a circle
    computation_result = abs((ind.x**2 + ind.y**2) - 1)
    # DEAP wants a tuple as fitness, ALWAYS!
    fitness_tuple = (computation_result ,)
    
    # we also require a dictionary with at least a single result for storing the results in the hdf
    result_dict = {}
    
    return fitness_tuple, result_dict

    
pars = ParameterSpace(['x', 'y'], [[-5.0, 5.0], [-5.0, 5.0]])
evolution = Evolution(optimize_me, pars, weightList = [-1.0],
                      POP_INIT_SIZE=10, POP_SIZE = 6, NGEN=4, filename="example-2.0.hdf")
# info: chose POP_INIT_SIZE=100, POP_SIZE = 50, NGEN=10 for real exploration, 
# values here are low for testing: POP_INIT_SIZE=10, POP_SIZE = 6, NGEN=4

evolution.run(verbose = True)
# Out:
# MainProcess root INFO     Assuming parameter kind "bound"
# MainProcess root INFO     Trajectory Name: results-2026-03-23-09H-54M-05S
# MainProcess root INFO     Storing data to: ./data/hdf/example-2.0.hdf
# MainProcess root INFO     Trajectory Name: results-2026-03-23-09H-54M-05S
# MainProcess root INFO     Number of cores: 128
# MainProcess pypet.storageservice.HDF5StorageService INFO     I will use the hdf5 file `./data/hdf/example-2.0.hdf`.
# MainProcess pypet.environment.Environment INFO     Environment initialized.
# MainProcess root INFO     Evolution: Using algorithm: adaptive
# /beegfs_hdd/data/nfs_share/users/guiyun/nishome/virtualbrain/.venv/lib/python3.13/site-packages/deap/creator.py:185: RuntimeWarning: A class named 'FitnessMulti' has already been created and it will be overwritten. Consider deleting previous creation of that class or rename it.
#   warnings.warn("A class named '{0}' has already been created and it "
# /beegfs_hdd/data/nfs_share/users/guiyun/nishome/virtualbrain/.venv/lib/python3.13/site-packages/deap/creator.py:185: RuntimeWarning: A class named 'Individual' has already been created and it will be overwritten. Consider deleting previous creation of that class or rename it.
#   warnings.warn("A class named '{0}' has already been created and it "
# MainProcess root INFO     Evolution: Individual generation: <function randomParametersAdaptive at 0x7fe476331bc0>
# MainProcess root INFO     Evolution: Mating operator: <function cxBlend at 0x7fe476d4a2a0>
# MainProcess root INFO     Evolution: Mutation operator: <function gaussianAdaptiveMutation_nStepSizes at 0x7fe4763320c0>
# MainProcess root INFO     Evolution: Parent selection: <function selRank at 0x7fe476331da0>
# MainProcess root INFO     Evolution: Selection operator: <function selBest_multiObj at 0x7fe476331e40>
# MainProcess root INFO     Evaluating initial population of size 10 ...
# MainProcess pypet.trajectory.Trajectory INFO     Your trajectory has not been explored, yet. I will call `f_explore` instead.
# MainProcess pypet.environment.Environment INFO     I am preparing the Trajectory for the experiment and initialise the store.
# MainProcess pypet.environment.Environment INFO     Initialising the storage for the trajectory.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2026-03-23-09H-54M-05S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2026-03-23-09H-54M-05S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# STARTING runs of trajectory
# `results-2026-03-23-09H-54M-05S`.
# ************************************************************
#
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2026-03-23-09H-54M-05S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2026-03-23-09H-54M-05S`.
# MainProcess pypet.environment.Environment INFO     Starting multiprocessing with at most 128 processes running at the same time.
# MainProcess pypet INFO     PROGRESS: Finished  0/10 runs [                    ]  0.0%
# MainProcess pypet INFO     PROGRESS: Finished  1/10 runs [==                  ] 10.0%, remaining: 0:00:00
# MainProcess pypet INFO     PROGRESS: Finished  2/10 runs [====                ] 20.0%, remaining: 0:00:00
# MainProcess pypet INFO     PROGRESS: Finished  3/10 runs [======              ] 30.0%, remaining: 0:00:00
# MainProcess pypet INFO     PROGRESS: Finished  4/10 runs [========            ] 40.0%, remaining: 0:00:00
# MainProcess pypet INFO     PROGRESS: Finished  5/10 runs [==========          ] 50.0%, remaining: 0:00:00
# MainProcess pypet INFO     PROGRESS: Finished  6/10 runs [============        ] 60.0%, remaining: 0:00:00
# MainProcess pypet INFO     PROGRESS: Finished  7/10 runs [==============      ] 70.0%, remaining: 0:00:00
# MainProcess pypet INFO     PROGRESS: Finished  8/10 runs [================    ] 80.0%, remaining: 0:00:00
# MainProcess pypet INFO     PROGRESS: Finished  9/10 runs [==================  ] 90.0%, remaining: 0:00:00
# MainProcess pypet INFO     PROGRESS: Finished 10/10 runs [====================]100.0%
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2026-03-23-09H-54M-05S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2026-03-23-09H-54M-05S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# FINISHED all runs of trajectory
# `results-2026-03-23-09H-54M-05S`.
# ************************************************************
#
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# STARTING FINAL STORING of trajectory
# `results-2026-03-23-09H-54M-05S`
# ************************************************************
#
# MainProcess pypet.storageservice.HDF5StorageService INFO     Start storing Trajectory `results-2026-03-23-09H-54M-05S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `config`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `results`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `derived_parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished storing Trajectory `results-2026-03-23-09H-54M-05S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# FINISHED FINAL STORING of trajectory
# `results-2026-03-23-09H-54M-05S`.
# ************************************************************
#
# MainProcess pypet.environment.Environment INFO     All runs of trajectory `results-2026-03-23-09H-54M-05S` were completed successfully.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Start storing Trajectory `results-2026-03-23-09H-54M-05S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `config`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `results`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `derived_parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished storing Trajectory `results-2026-03-23-09H-54M-05S`.
# MainProcess root INFO     Start of evolution
# Parameter distribution (Generation 0):
# x: 	 mean: -0.1562,	 std: 2.8348
# y: 	 mean: 1.4382,	 std: 3.2651
# MainProcess root INFO     Replacing 0 invalid individuals.
# MainProcess pypet.environment.Environment INFO     I am preparing the Trajectory for the experiment and initialise the store.
# MainProcess pypet.environment.Environment INFO     Initialising the storage for the trajectory.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2026-03-23-09H-54M-05S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2026-03-23-09H-54M-05S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# STARTING runs of trajectory
# `results-2026-03-23-09H-54M-05S`.
# ************************************************************
#
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2026-03-23-09H-54M-05S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2026-03-23-09H-54M-05S`.
# MainProcess pypet.environment.Environment INFO     Starting multiprocessing with at most 128 processes running at the same time.
# MainProcess pypet INFO     PROGRESS: Finished 10/16 runs [============        ] 62.5%
# MainProcess pypet INFO     PROGRESS: Finished 11/16 runs [=============       ] 68.8%, remaining: 0:00:00
# MainProcess pypet INFO     PROGRESS: Finished 12/16 runs [===============     ] 75.0%, remaining: 0:00:00
# MainProcess pypet INFO     PROGRESS: Finished 13/16 runs [================    ] 81.2%, remaining: 0:00:00
# MainProcess pypet INFO     PROGRESS: Finished 14/16 runs [=================   ] 87.5%, remaining: 0:00:00
# MainProcess pypet INFO     PROGRESS: Finished 15/16 runs [==================  ] 93.8%, remaining: 0:00:00
# MainProcess pypet INFO     PROGRESS: Finished 16/16 runs [====================]100.0%
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2026-03-23-09H-54M-05S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2026-03-23-09H-54M-05S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# FINISHED all runs of trajectory
# `results-2026-03-23-09H-54M-05S`.
# ************************************************************
#
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# STARTING FINAL STORING of trajectory
# `results-2026-03-23-09H-54M-05S`
# ************************************************************
#
# MainProcess pypet.storageservice.HDF5StorageService INFO     Start storing Trajectory `results-2026-03-23-09H-54M-05S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `config`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `results`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `derived_parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished storing Trajectory `results-2026-03-23-09H-54M-05S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# FINISHED FINAL STORING of trajectory
# `results-2026-03-23-09H-54M-05S`.
# ************************************************************
#
# MainProcess pypet.environment.Environment INFO     All runs of trajectory `results-2026-03-23-09H-54M-05S` were completed successfully.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Start storing Trajectory `results-2026-03-23-09H-54M-05S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `config`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `results`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `derived_parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished storing Trajectory `results-2026-03-23-09H-54M-05S`.
# /beegfs_hdd/data/nfs_share/users/guiyun/nishome/virtualbrain/src/neurolib/neurolib/optimize/evolution/evolutionaryUtils.py:238: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# ----------- Generation 1 -----------
# Best individual is [-0.6746235708678014, 0.5664808740773601, 3.3333333333333335, 3.3333333333333335]
# Score: -0.22398245693412644
# Fitness: (0.22398245693412644,)
# --- Population statistics ---
# > Simulation parameters
# HDF file storage: ./data/hdf/example-2.0.hdf
# Trajectory Name: results-2026-03-23-09H-54M-05S
# Duration of evaluating initial population 0:00:01.812204
# Eval function: <function optimize_me at 0x7fe4a361db20>
# Parameter space: {'x': [-5.0, 5.0], 'y': [-5.0, 5.0]}
# > Evolution parameters
# Number of generations: 4
# Initial population size: 10
# Population size: 6
# > Evolutionary operators
# Mating operator: <function cxBlend at 0x7fe476d4a2a0>
# Mating paramter: {'alpha': 0.5}
# Selection operator: <function selBest_multiObj at 0x7fe476331e40>
# Selection paramter: {}
# Parent selection operator: <function selRank at 0x7fe476331da0>
# Comments: no comments
# --- Info summary ---
# Valid: 6
# Mean score (weighted fitness): -4.1
# Parameter distribution (Generation 1):
# x: 	 mean: -0.7710,	 std: 1.2243
# y: 	 mean: 0.1910,	 std: 1.6022
# --------------------
# Best 5 individuals:
# Printing 5 individuals
# Individual 0
# 	Fitness values:  0.22
# 	Score:  -0.22
# 	Weighted fitness:  -0.22
# 	Stats mean 0.22 std 0.00 min 0.22 max 0.22
# 	model.params["x"] = -0.67
# 	model.params["y"] = 0.57
# Individual 1
# 	Fitness values:  0.85
# 	Score:  -0.85
# 	Weighted fitness:  -0.85
# 	Stats mean 0.85 std 0.00 min 0.85 max 0.85
# 	model.params["x"] = -0.38
# 	model.params["y"] = -0.09
# Individual 2
# 	Fitness values:  2.58
# 	Score:  -2.58
# 	Weighted fitness:  -2.58
# 	Stats mean 2.58 std 0.00 min 2.58 max 2.58
# 	model.params["x"] = -1.67
# 	model.params["y"] = 0.89
# Individual 3
# 	Fitness values:  2.72
# 	Score:  -2.72
# 	Weighted fitness:  -2.72
# 	Stats mean 2.72 std 0.00 min 2.72 max 2.72
# 	model.params["x"] = -0.03
# 	model.params["y"] = 1.93
# Individual 4
# 	Fitness values:  8.17
# 	Score:  -8.17
# 	Weighted fitness:  -8.17
# 	Stats mean 8.17 std 0.00 min 8.17 max 8.17
# 	model.params["x"] = -2.86
# 	model.params["y"] = 0.98
# --------------------
# MainProcess root INFO     Saving plot to ./data/figures/results-2026-03-23-09H-54M-05S_hist_1.png
# There are 6 valid individuals
# Mean score across population: -4.1
# MainProcess root INFO     Replacing 0 invalid individuals.
# MainProcess pypet.environment.Environment INFO     I am preparing the Trajectory for the experiment and initialise the store.
# MainProcess pypet.environment.Environment INFO     Initialising the storage for the trajectory.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2026-03-23-09H-54M-05S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2026-03-23-09H-54M-05S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# STARTING runs of trajectory
# `results-2026-03-23-09H-54M-05S`.
# ************************************************************
#
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2026-03-23-09H-54M-05S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2026-03-23-09H-54M-05S`.
# MainProcess pypet.environment.Environment INFO     Starting multiprocessing with at most 128 processes running at the same time.
# MainProcess pypet INFO     PROGRESS: Finished 16/22 runs [==============      ] 72.7%
# MainProcess pypet INFO     PROGRESS: Finished 17/22 runs [===============     ] 77.3%, remaining: 0:00:00
# MainProcess pypet INFO     PROGRESS: Finished 18/22 runs [================    ] 81.8%, remaining: 0:00:00
# MainProcess pypet INFO     PROGRESS: Finished 19/22 runs [=================   ] 86.4%, remaining: 0:00:00
# MainProcess pypet INFO     PROGRESS: Finished 20/22 runs [==================  ] 90.9%, remaining: 0:00:00
# MainProcess pypet INFO     PROGRESS: Finished 21/22 runs [=================== ] 95.5%, remaining: 0:00:00
# MainProcess pypet INFO     PROGRESS: Finished 22/22 runs [====================]100.0%
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2026-03-23-09H-54M-05S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2026-03-23-09H-54M-05S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# FINISHED all runs of trajectory
# `results-2026-03-23-09H-54M-05S`.
# ************************************************************
#
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# STARTING FINAL STORING of trajectory
# `results-2026-03-23-09H-54M-05S`
# ************************************************************
#
# MainProcess pypet.storageservice.HDF5StorageService INFO     Start storing Trajectory `results-2026-03-23-09H-54M-05S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `config`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `results`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `derived_parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished storing Trajectory `results-2026-03-23-09H-54M-05S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# FINISHED FINAL STORING of trajectory
# `results-2026-03-23-09H-54M-05S`.
# ************************************************************
#
# MainProcess pypet.environment.Environment INFO     All runs of trajectory `results-2026-03-23-09H-54M-05S` were completed successfully.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Start storing Trajectory `results-2026-03-23-09H-54M-05S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `config`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `results`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `derived_parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished storing Trajectory `results-2026-03-23-09H-54M-05S`.
# /beegfs_hdd/data/nfs_share/users/guiyun/nishome/virtualbrain/src/neurolib/neurolib/optimize/evolution/evolutionaryUtils.py:238: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# ----------- Generation 2 -----------
# Best individual is [-0.6746235708678014, 0.5664808740773601, 3.3333333333333335, 3.3333333333333335]
# Score: -0.22398245693412644
# Fitness: (0.22398245693412644,)
# --- Population statistics ---
# > Simulation parameters
# HDF file storage: ./data/hdf/example-2.0.hdf
# Trajectory Name: results-2026-03-23-09H-54M-05S
# Duration of evaluating initial population 0:00:01.812204
# Eval function: <function optimize_me at 0x7fe4a361db20>
# Parameter space: {'x': [-5.0, 5.0], 'y': [-5.0, 5.0]}
# > Evolution parameters
# Number of generations: 4
# Initial population size: 10
# Population size: 6
# > Evolutionary operators
# Mating operator: <function cxBlend at 0x7fe476d4a2a0>
# Mating paramter: {'alpha': 0.5}
# Selection operator: <function selBest_multiObj at 0x7fe476331e40>
# Selection paramter: {}
# Parent selection operator: <function selRank at 0x7fe476331da0>
# Comments: no comments
# --- Info summary ---
# Valid: 6
# Mean score (weighted fitness): -1.1
# Parameter distribution (Generation 2):
# x: 	 mean: -0.8734,	 std: 0.6377
# y: 	 mean: 0.2901,	 std: 0.4480
# --------------------
# Best 5 individuals:
# Printing 5 individuals
# Individual 0
# 	Fitness values:  0.22
# 	Score:  -0.22
# 	Weighted fitness:  -0.22
# 	Stats mean 0.22 std 0.00 min 0.22 max 0.22
# 	model.params["x"] = -0.67
# 	model.params["y"] = 0.57
# Individual 1
# 	Fitness values:  0.42
# 	Score:  -0.42
# 	Weighted fitness:  -0.42
# 	Stats mean 0.42 std 0.00 min 0.42 max 0.42
# 	model.params["x"] = -1.15
# 	model.params["y"] = 0.31
# Individual 2
# 	Fitness values:  0.76
# 	Score:  -0.76
# 	Weighted fitness:  -0.76
# 	Stats mean 0.76 std 0.00 min 0.76 max 0.76
# 	model.params["x"] = 0.14
# 	model.params["y"] = -0.46
# Individual 3
# 	Fitness values:  0.85
# 	Score:  -0.85
# 	Weighted fitness:  -0.85
# 	Stats mean 0.85 std 0.00 min 0.85 max 0.85
# 	model.params["x"] = -0.38
# 	model.params["y"] = -0.09
# Individual 4
# 	Fitness values:  1.56
# 	Score:  -1.56
# 	Weighted fitness:  -1.56
# 	Stats mean 1.56 std 0.00 min 1.56 max 1.56
# 	model.params["x"] = -1.51
# 	model.params["y"] = 0.53
# --------------------
# MainProcess root INFO     Saving plot to ./data/figures/results-2026-03-23-09H-54M-05S_hist_2.png
# There are 6 valid individuals
# Mean score across population: -1.1
# MainProcess root INFO     Replacing 0 invalid individuals.
# MainProcess pypet.environment.Environment INFO     I am preparing the Trajectory for the experiment and initialise the store.
# MainProcess pypet.environment.Environment INFO     Initialising the storage for the trajectory.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2026-03-23-09H-54M-05S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2026-03-23-09H-54M-05S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# STARTING runs of trajectory
# `results-2026-03-23-09H-54M-05S`.
# ************************************************************
#
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2026-03-23-09H-54M-05S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2026-03-23-09H-54M-05S`.
# MainProcess pypet.environment.Environment INFO     Starting multiprocessing with at most 128 processes running at the same time.
# MainProcess pypet INFO     PROGRESS: Finished 22/28 runs [===============     ] 78.6%
# MainProcess pypet INFO     PROGRESS: Finished 23/28 runs [================    ] 82.1%, remaining: 0:00:00
# MainProcess pypet INFO     PROGRESS: Finished 24/28 runs [=================   ] 85.7%, remaining: 0:00:00
# MainProcess pypet INFO     PROGRESS: Finished 26/28 runs [==================  ] 92.9%, remaining: 0:00:00
# MainProcess pypet INFO     PROGRESS: Finished 27/28 runs [=================== ] 96.4%, remaining: 0:00:00
# MainProcess pypet INFO     PROGRESS: Finished 28/28 runs [====================]100.0%
# MainProcess pypet.storageservice.HDF5StorageService INFO     Initialising storage or updating meta data of Trajectory `results-2026-03-23-09H-54M-05S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished init or meta data update for `results-2026-03-23-09H-54M-05S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# FINISHED all runs of trajectory
# `results-2026-03-23-09H-54M-05S`.
# ************************************************************
#
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# STARTING FINAL STORING of trajectory
# `results-2026-03-23-09H-54M-05S`
# ************************************************************
#
# MainProcess pypet.storageservice.HDF5StorageService INFO     Start storing Trajectory `results-2026-03-23-09H-54M-05S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `config`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `results`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `derived_parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished storing Trajectory `results-2026-03-23-09H-54M-05S`.
# MainProcess pypet.environment.Environment INFO
# ************************************************************
# FINISHED FINAL STORING of trajectory
# `results-2026-03-23-09H-54M-05S`.
# ************************************************************
#
# MainProcess pypet.environment.Environment INFO     All runs of trajectory `results-2026-03-23-09H-54M-05S` were completed successfully.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Start storing Trajectory `results-2026-03-23-09H-54M-05S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `config`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `results`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `derived_parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished storing Trajectory `results-2026-03-23-09H-54M-05S`.
# /beegfs_hdd/data/nfs_share/users/guiyun/nishome/virtualbrain/src/neurolib/neurolib/optimize/evolution/evolutionaryUtils.py:238: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# ----------- Generation 3 -----------
# Best individual is [0.887063641695862, 0.5151049284551681, -1.0795605993590611, 1.3342948674479231]
# Score: -0.05221499173752853
# Fitness: (0.05221499173752853,)
# --- Population statistics ---
# > Simulation parameters
# HDF file storage: ./data/hdf/example-2.0.hdf
# Trajectory Name: results-2026-03-23-09H-54M-05S
# Duration of evaluating initial population 0:00:01.812204
# Eval function: <function optimize_me at 0x7fe4a361db20>
# Parameter space: {'x': [-5.0, 5.0], 'y': [-5.0, 5.0]}
# > Evolution parameters
# Number of generations: 4
# Initial population size: 10
# Population size: 6
# > Evolutionary operators
# Mating operator: <function cxBlend at 0x7fe476d4a2a0>
# Mating paramter: {'alpha': 0.5}
# Selection operator: <function selBest_multiObj at 0x7fe476331e40>
# Selection paramter: {}
# Parent selection operator: <function selRank at 0x7fe476331da0>
# Comments: no comments
# --- Info summary ---
# Valid: 6
# Mean score (weighted fitness): -0.54
# Parameter distribution (Generation 3):
# x: 	 mean: -0.1707,	 std: 0.6552
# y: 	 mean: 0.1700,	 std: 0.3570
# --------------------
# Best 5 individuals:
# Printing 5 individuals
# Individual 0
# 	Fitness values:  0.05
# 	Score:  -0.05
# 	Weighted fitness:  -0.05
# 	Stats mean 0.05 std 0.00 min 0.05 max 0.05
# 	model.params["x"] = 0.89
# 	model.params["y"] = 0.52
# Individual 1
# 	Fitness values:  0.22
# 	Score:  -0.22
# 	Weighted fitness:  -0.22
# 	Stats mean 0.22 std 0.00 min 0.22 max 0.22
# 	model.params["x"] = -0.67
# 	model.params["y"] = 0.57
# Individual 2
# 	Fitness values:  0.42
# 	Score:  -0.42
# 	Weighted fitness:  -0.42
# 	Stats mean 0.42 std 0.00 min 0.42 max 0.42
# 	model.params["x"] = -1.15
# 	model.params["y"] = 0.31
# Individual 3
# 	Fitness values:  0.76
# 	Score:  -0.76
# 	Weighted fitness:  -0.76
# 	Stats mean 0.76 std 0.00 min 0.76 max 0.76
# 	model.params["x"] = 0.14
# 	model.params["y"] = -0.46
# Individual 4
# 	Fitness values:  0.85
# 	Score:  -0.85
# 	Weighted fitness:  -0.85
# 	Stats mean 0.85 std 0.00 min 0.85 max 0.85
# 	model.params["x"] = -0.38
# 	model.params["y"] = -0.09
# --------------------
# MainProcess root INFO     Saving plot to ./data/figures/results-2026-03-23-09H-54M-05S_hist_3.png
# There are 6 valid individuals
# Mean score across population: -0.54
# MainProcess root INFO     --- End of evolution ---
# MainProcess root INFO     Best individual is [0.887063641695862, 0.5151049284551681, -1.0795605993590611, 1.3342948674479231], (0.05221499173752853,)
# MainProcess root INFO     --- End of evolution ---
# MainProcess pypet.storageservice.HDF5StorageService INFO     Start storing Trajectory `results-2026-03-23-09H-54M-05S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `config`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `results`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Storing branch `derived_parameters`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Finished storing Trajectory `results-2026-03-23-09H-54M-05S`.

# %%
evolution.loadResults()
# Out:
# MainProcess root INFO     Loading results from ./data/hdf/example-2.0.hdf
# MainProcess root INFO     Analyzing trajectory results-2026-03-23-09H-54M-05S
# MainProcess pypet.storageservice.HDF5StorageService INFO     I will use the hdf5 file `./data/hdf/example-2.0.hdf`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Loading trajectory `results-2026-03-23-09H-54M-05S`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Loading branch `config` in mode `2`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Loading branch `derived_parameters` in mode `1`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Loading branch `parameters` in mode `2`.
# MainProcess pypet.storageservice.HDF5StorageService INFO     Loading branch `results` in mode `1`.

# %%
evolution.info(plot=True)
# Out:
# > Simulation parameters
# HDF file storage: ./data/hdf/example-2.0.hdf
# Trajectory Name: results-2026-03-23-09H-54M-05S
# Duration of evaluating initial population 0:00:01.812204
# Duration of evolution 0:00:13.365801
# Eval function: <function optimize_me at 0x7fe4a361db20>
# Parameter space: {'x': [-5.0, 5.0], 'y': [-5.0, 5.0]}
# > Evolution parameters
# Number of generations: 4
# Initial population size: 10
# Population size: 6
# > Evolutionary operators
# Mating operator: <function cxBlend at 0x7fe476d4a2a0>
# Mating paramter: {'alpha': 0.5}
# Selection operator: <function selBest_multiObj at 0x7fe476331e40>
# Selection paramter: {}
# Parent selection operator: <function selRank at 0x7fe476331da0>
# Comments: no comments
# --- Info summary ---
# Valid: 6
# Mean score (weighted fitness): -0.54
# Parameter distribution (Generation 3):
# x: 	 mean: -0.1707,	 std: 0.6552
# y: 	 mean: 0.1700,	 std: 0.3570
# --------------------
# Best 5 individuals:
# Printing 5 individuals
# Individual 0
# 	Fitness values:  0.05
# 	Score:  -0.05
# 	Weighted fitness:  -0.05
# 	Stats mean 0.05 std 0.00 min 0.05 max 0.05
# 	model.params["x"] = 0.89
# 	model.params["y"] = 0.52
# Individual 1
# 	Fitness values:  0.22
# 	Score:  -0.22
# 	Weighted fitness:  -0.22
# 	Stats mean 0.22 std 0.00 min 0.22 max 0.22
# 	model.params["x"] = -0.67
# 	model.params["y"] = 0.57
# Individual 2
# 	Fitness values:  0.42
# 	Score:  -0.42
# 	Weighted fitness:  -0.42
# 	Stats mean 0.42 std 0.00 min 0.42 max 0.42
# 	model.params["x"] = -1.15
# 	model.params["y"] = 0.31
# Individual 3
# 	Fitness values:  0.76
# 	Score:  -0.76
# 	Weighted fitness:  -0.76
# 	Stats mean 0.76 std 0.00 min 0.76 max 0.76
# 	model.params["x"] = 0.14
# 	model.params["y"] = -0.46
# Individual 4
# 	Fitness values:  0.85
# 	Score:  -0.85
# 	Weighted fitness:  -0.85
# 	Stats mean 0.85 std 0.00 min 0.85 max 0.85
# 	model.params["x"] = -0.38
# 	model.params["y"] = -0.09
# --------------------
# /beegfs_hdd/data/nfs_share/users/guiyun/nishome/virtualbrain/src/neurolib/neurolib/optimize/evolution/evolutionaryUtils.py:238: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# MainProcess root INFO     Saving plot to ./data/figures/results-2026-03-23-09H-54M-05S_hist_3.png
# There are 6 valid individuals
# Mean score across population: -0.54

# %%
gens, all_scores = evolution.getScoresDuringEvolution(reverse=True)

import matplotlib.pyplot as plt
plt.figure(figsize=(8, 4), dpi=200)   
plt.plot(gens, np.nanmean(all_scores, axis=1))
plt.fill_between(gens, np.nanmin(all_scores, axis=1), np.nanmax(all_scores, axis=1), alpha=0.3)
plt.xlabel("Generation #")
plt.ylabel("Score")
# Out:
# Text(0, 0.5, 'Score')
